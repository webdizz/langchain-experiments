# %%
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

# %% [markdown]
# ## LangChain Q&A over documents

# %%
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import CSVLoader
from langchain.vectorstores import DocArrayInMemorySearch
from IPython.display import display, Markdown

# %%
file = "../data/OutdoorClothingCatalog_1000.csv"
loader = CSVLoader(file_path=file, csv_args={"delimiter": ";"})

# %%
from langchain.indexes import VectorstoreIndexCreator

# %%
index = VectorstoreIndexCreator(vectorstore_cls=DocArrayInMemorySearch).from_loaders(
    [loader]
)

# %%
query = "Please list all your shirts with sun protection \ in a table in markdown and summarize each one"

# %%
response = index.query(query)

# %%
response
# Out:
# " I'm sorry, I don't know."

# %%
display(Markdown(response))
# Out:
#  I don't know.

# %%
loader = CSVLoader(file, csv_args={"delimiter": ";"})

# %%
docs = loader.load()

# %%
docs[0]
# Out:
# Document(page_content="name: Men's  Classic Denim, Standard Fit\ndescription: Crafted from premium denim that will last wash after wash, our 1912 Standard Fit jeans are prewashed for unbeatable comfort right from the start. \\n\\nSize & Fit\\nStandard Fit: Sits lower on the waist and straight through the hip and thigh for a streamlined look.\\n\\nWhy We Love Them\\nCustomers rave that these jeans “look great and feel great” while also telling us that the “cut and fit are perfect.” We make them from premium ring-spun denim, known for its strength, softness and authentic vintage character.\\n\\nFabric & Care\\n100% cotton. Machine wash and dry. Imported.", metadata={'source': '../data/OutdoorClothingCatalog_1000.csv', 'row': 0})

# %%
from langchain.embeddings import OpenAIEmbeddings

# %%
embeddings = OpenAIEmbeddings()

# %%
embed = embeddings.embed_query("Hi my name is Izzet")

# %%
len(embed)
# Out:
# 1536

# %%
embed[:5]
# Out:
# [-0.030722320079803467,
#  -0.020306454971432686,
#  -0.032387834042310715,
#  -0.03502703085541725,
#  -0.012215902097523212]

# %%
db = DocArrayInMemorySearch.from_documents(docs, embeddings)

# %%
query = "Please suggest a shirt with sunblocking"

# %%
docs = db.similarity_search(query)

# %%
list(docs)
# Out:
# [Document(page_content="name: Women's Stop Flies Hoodie\ndescription: This great-looking hoodie uses No Fly Zone Technology to repel ticks, mosquitoes, flies and other biting insects, while also providing UPF 40+ sun protection. It is slightly fitted to softly shape the body, and falls at the hip for added coverage. With this bug repellent clothing, you can make the most of a day outside and enjoy freedom of movement. It is designed with comfortable fabric that is breathable and wicks away moisture from your body. The fabric is a blend of 64% polyester, 33% cotton, and 3% spandex. Treat it with care by machine washing and drying. The lightweight, low-profile hood will keep the sun and bugs off without being too bulky. You'll also stay comfortable with the wrist and cuff that won't ride up and the thumbhole for added coverage. With the No Fly Zone treatment lasting through 70 washings, you can tell biting insects to take a hike!", metadata={'source': '../data/OutdoorClothingCatalog_1000.csv', 'row': 3}),
#  Document(page_content="name: Women's NRS Endurance Spray Paddling Pants\ndescription: These comfortable and affordable splash paddling pants are designed to keep out the wind and splashing water, making them perfect for canoeing or paddleboarding in cooler weather. Fabric & Care: 40-denier HyproTex™ 2.5 waterproof, breathable fabric. Handwash, line dry. Construction: Made from waterproof, breathable HyproTex™ 2.5 fabric that lets excess heat and moisture escape. The generous cut allows for easy layering underneath without restricting movement. The high-rise design and wide neoprene waistband deliver optimal coverage even when sitting. Dual hook-and-loop adjustments allow you to cinch the neoprene waistband for a custom fit. Reinforced seat and knees add extra durability in high-wear areas. A splashproof thigh pocket keeps small essentials handy. Imported.", metadata={'source': '../data/OutdoorClothingCatalog_1000.csv', 'row': 2}),
#  Document(page_content="name: CozyPrint Sweater Fleece Pullover\ndescription: The ultimate sweater fleece - made from superior fabric and offered at an unbeatable price.\\n\\nSize & Fit: Slightly Fitted: Softly shapes the body.\\n\\nWhy We Love It: Our customers (and employees) love the rugged construction and heritage-inspired styling of our popular Sweater Fleece Pullover and wear it for absolutely everything. From high-intensity activities to everyday tasks, you'll find yourself reaching for it every time.\\n\\nFabric & Care: Rugged sweater-knit exterior and soft brushed interior for exceptional warmth and comfort. Made in soft, 100% polyester. Machine wash and dry.\\n\\nAdditional Features: Features our classic Mount Katahdin logo. Front princess seams create a feminine shape. Kangaroo handwarmer pockets. Cuffs and hem reinforced with jersey binding. Imported.", metadata={'source': '../data/OutdoorClothingCatalog_1000.csv', 'row': 1}),
#  Document(page_content='name: Modern Utility Bag\ndescription: This US-made crossbody bag is built with the same legendary quality as our Original Boat and Totes. Built with tough materials and generous organizational features, it\\\'s perfect for work, town, the beach and much more. \\n\\nSpecs\\nDimensions: 17"H x 13"W x 5.5"D. \\nCapacity: Approx. 1,215 cu. in. \\n\\nWhy We Love It\\nOur Maine-made crossbody bag is both stylish and functional. It has the capacity to carry a generous load of beach gear or personal items. When not full, the top folds down to create an eye-catching bag for treks around town. \\n\\nFabric & Care\\nSpot clean. \\nConstruction\\nMain body and base fabric are rugged 1000-denier Cordura nylon. \\nAntiqued brass metal hardware and rivets.\\nSeams are stitched with a heavy-duty nylon thread for durability. \\nAttractive leather handles and trim details. \\nAdjustable shoulder strap.\\n\\nAdditional Features\\nDetachable, adjustable crossbody shoulder strap. \\nHandy exterior pocket for smaller necessities. \\nInterior zippered apron pocket with key fob', metadata={'source': '../data/OutdoorClothingCatalog_1000.csv', 'row': 4})]

# %%
docs[0]
# Out:
# Document(page_content="name: Women's Stop Flies Hoodie\ndescription: This great-looking hoodie uses No Fly Zone Technology to repel ticks, mosquitoes, flies and other biting insects, while also providing UPF 40+ sun protection. It is slightly fitted to softly shape the body, and falls at the hip for added coverage. With this bug repellent clothing, you can make the most of a day outside and enjoy freedom of movement. It is designed with comfortable fabric that is breathable and wicks away moisture from your body. The fabric is a blend of 64% polyester, 33% cotton, and 3% spandex. Treat it with care by machine washing and drying. The lightweight, low-profile hood will keep the sun and bugs off without being too bulky. You'll also stay comfortable with the wrist and cuff that won't ride up and the thumbhole for added coverage. With the No Fly Zone treatment lasting through 70 washings, you can tell biting insects to take a hike!", metadata={'source': '../data/OutdoorClothingCatalog_1000.csv', 'row': 3})

# %%
len(docs)
# Out:
# 4

# %%
retriever = db.as_retriever()

# %%
llm = ChatOpenAI(temperature=0)

# %%
qdocs = "".join([docs[i].page_content for i in range(len(docs))])

# %%
qdocs
# Out:
# 'name: Women\'s Stop Flies Hoodie\ndescription: This great-looking hoodie uses No Fly Zone Technology to repel ticks, mosquitoes, flies and other biting insects, while also providing UPF 40+ sun protection. It is slightly fitted to softly shape the body, and falls at the hip for added coverage. With this bug repellent clothing, you can make the most of a day outside and enjoy freedom of movement. It is designed with comfortable fabric that is breathable and wicks away moisture from your body. The fabric is a blend of 64% polyester, 33% cotton, and 3% spandex. Treat it with care by machine washing and drying. The lightweight, low-profile hood will keep the sun and bugs off without being too bulky. You\'ll also stay comfortable with the wrist and cuff that won\'t ride up and the thumbhole for added coverage. With the No Fly Zone treatment lasting through 70 washings, you can tell biting insects to take a hike!name: Women\'s NRS Endurance Spray Paddling Pants\ndescription: These comfortable and affordable splash paddling pants are designed to keep out the wind and splashing water, making them perfect for canoeing or paddleboarding in cooler weather. Fabric & Care: 40-denier HyproTex™ 2.5 waterproof, breathable fabric. Handwash, line dry. Construction: Made from waterproof, breathable HyproTex™ 2.5 fabric that lets excess heat and moisture escape. The generous cut allows for easy layering underneath without restricting movement. The high-rise design and wide neoprene waistband deliver optimal coverage even when sitting. Dual hook-and-loop adjustments allow you to cinch the neoprene waistband for a custom fit. Reinforced seat and knees add extra durability in high-wear areas. A splashproof thigh pocket keeps small essentials handy. Imported.name: CozyPrint Sweater Fleece Pullover\ndescription: The ultimate sweater fleece - made from superior fabric and offered at an unbeatable price.\\n\\nSize & Fit: Slightly Fitted: Softly shapes the body.\\n\\nWhy We Love It: Our customers (and employees) love the rugged construction and heritage-inspired styling of our popular Sweater Fleece Pullover and wear it for absolutely everything. From high-intensity activities to everyday tasks, you\'ll find yourself reaching for it every time.\\n\\nFabric & Care: Rugged sweater-knit exterior and soft brushed interior for exceptional warmth and comfort. Made in soft, 100% polyester. Machine wash and dry.\\n\\nAdditional Features: Features our classic Mount Katahdin logo. Front princess seams create a feminine shape. Kangaroo handwarmer pockets. Cuffs and hem reinforced with jersey binding. Imported.name: Modern Utility Bag\ndescription: This US-made crossbody bag is built with the same legendary quality as our Original Boat and Totes. Built with tough materials and generous organizational features, it\\\'s perfect for work, town, the beach and much more. \\n\\nSpecs\\nDimensions: 17"H x 13"W x 5.5"D. \\nCapacity: Approx. 1,215 cu. in. \\n\\nWhy We Love It\\nOur Maine-made crossbody bag is both stylish and functional. It has the capacity to carry a generous load of beach gear or personal items. When not full, the top folds down to create an eye-catching bag for treks around town. \\n\\nFabric & Care\\nSpot clean. \\nConstruction\\nMain body and base fabric are rugged 1000-denier Cordura nylon. \\nAntiqued brass metal hardware and rivets.\\nSeams are stitched with a heavy-duty nylon thread for durability. \\nAttractive leather handles and trim details. \\nAdjustable shoulder strap.\\n\\nAdditional Features\\nDetachable, adjustable crossbody shoulder strap. \\nHandy exterior pocket for smaller necessities. \\nInterior zippered apron pocket with key fob'

# %%
response = llm.call_as_llm(f"{qdocs} Question: Please list shirts with sun protection in a table in markdown and summarize each one.")

# %%
display(Markdown(response))
# Out:
# | Name                           | Description

# %%
qa_stuff = RetrievalQA.from_chain_type(
    llm=llm, chain_type="stuff", retriever=retriever, verbose=True
)

# %%
response = qa_stuff.run(query)
# Out:
# > Entering new RetrievalQA chain...
#
# > Finished chain.

# %%
response = index.query(query, llm=llm)

# %%
index = VectorstoreIndexCreator(
    vectorstore_cls=DocArrayInMemorySearch,
    embedding=embeddings,
).from_loaders([loader])
